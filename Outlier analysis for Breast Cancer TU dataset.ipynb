# %%
import pandas as pd
import numpy as np
from pycaret.anomaly import *

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
dataset = pd.read_csv(r'C:\Users\ClinAsia1\VisualStudio\PoC Anomaly  and Missing Value analysis (MaxisIT)\oulier dataset\Breast Cancer\tu.csv')
dataset
# Out:
#                     STUDYID DOMAIN           USUBJID  TUSEQ TULNKID  TUTESTCD  \
# 1          Breast Diagnosis     TU  BreastDx-01-0001      1     T01  TUMIDENT
# 2          Breast Diagnosis     TU  BreastDx-01-0002      2     T01  TUMIDENT
# 3          Breast Diagnosis     TU  BreastDx-01-0003      3     T01  TUMIDENT
# 4          Breast Diagnosis     TU  BreastDx-01-0004      4     T01  TUMIDENT
# 5          Breast Diagnosis     TU  BreastDx-01-0004      5     T01  TUMIDENT
# 6          Breast Diagnosis     TU  BreastDx-01-0005      6     T01  TUMIDENT
# 7          Breast Diagnosis     TU  BreastDx-01-0005      7     T01  TUMIDENT
# 8          Breast Diagnosis     TU  BreastDx-01-0006      8     T01  TUMIDENT
# 9          Breast Diagnosis     TU  BreastDx-01-0007      9     T01  TUMIDENT
# 10         Breast Diagnosis     TU  BreastDx-01-0008     10     T01  TUMIDENT
# 11         Breast Diagnosis     TU  BreastDx-01-0008     11     T01  TUMIDENT
# ...

# %%
dataset.shape
# Out:
# (1622, 12)

# %%
data = dataset.sample(frac=0.95, random_state=786)
data_unseen = dataset.drop(data.index).reset_index(drop=True)
data.reset_index(drop=True, inplace=True)

print('Data for Modeling: ' + str(data.shape))
print('Unseen Data For Predictions: ' + str(data_unseen.shape))
# Out:
# Data for Modeling: (1541, 12)
# Unseen Data For Predictions: (81, 12)

# %%
anomaly_setup = setup(dataset, normalize=True, transformation=True,transformation_method='quantile',numeric_imputation='median', ignore_features = ['STUDYID','USUBJID','TUSEQ'])
# Out:
# Setup Succesfully Completed!
# <style  type="text/css" >
# #T_f99c6d40_e60c_11ea_bfce_7cb27d7d8dadrow2_col1,#T_f99c6d40_e60c_11ea_bfce_7cb27d7d8dadrow10_col1,#T_f99c6d40_e60c_11ea_bfce_7cb27d7d8dadrow12_col1{
#             background-color:  lightgreen;
#         }</style><table id="T_f99c6d40_e60c_11ea_bfce_7cb27d7d8dad" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f99c6d40_e60c_11ea_bfce_7cb27d7d8dadlevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_f99c6d40_e60c_11ea_bfce_7cb27d7d8dadrow0_col0" class="data row0 col0" >session_id </td>
#                         <td id="T_f99c6d40_e60c_11ea_bfce_7cb27d7d8dadrow0_col1" class="data row0 col1" >7949</td>
#             </tr>
#             <tr>
# ...

# %%
knn = create_model('knn')

# %%
print(knn)
# Out:
# KNN(algorithm='auto', contamination=0.05, leaf_size=30, method='largest',
#   metric='minkowski', metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#   radius=1.0)

# %%
knn_results = assign_model(knn)
knn_results.head()
# Out:
#             STUDYID DOMAIN           USUBJID  TUSEQ TULNKID  TUTESTCD  \
# 1  Breast Diagnosis     TU  BreastDx-01-0001      1     T01  TUMIDENT
# 2  Breast Diagnosis     TU  BreastDx-01-0002      2     T01  TUMIDENT
# 3  Breast Diagnosis     TU  BreastDx-01-0003      3     T01  TUMIDENT
# 4  Breast Diagnosis     TU  BreastDx-01-0004      4     T01  TUMIDENT
# 5  Breast Diagnosis     TU  BreastDx-01-0004      5     T01  TUMIDENT
#
#                  TUTEST TUORRES   TULOC  TULAT TUMETHOD       TUDTC  Label  \
# 1  Tumor Identification  TARGET  BREAST   LEFT      MRI   8/12/2008      0
# 2  Tumor Identification  TARGET  BREAST  RIGHT      MRI  11/25/2008      0
# 3  Tumor Identification  TARGET  BREAST   LEFT      MRI   4/19/2008      0
# 4  Tumor Identification  TARGET  BREAST   LEFT      MRI   4/11/2008      0
# 5  Tumor Identification  TARGET  BREAST   LEFT      MRI   8/11/2007      0
#
#       Score
# 1  0.000000
# 2  1.414214
# 3  0.000000
# 4  0.000000
# 5  1.414214

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
label_1 = knn_results['Label'] == 1

# %%
knn_results[label_1]
# Out:
#                     STUDYID DOMAIN           USUBJID  TUSEQ TULNKID  TUTESTCD  \
# 8          Breast Diagnosis     TU  BreastDx-01-0006      8     T01  TUMIDENT
# 70    Breast-MRI-NACT-Pilot     TU        UCSF-BR-03     70     T01  TUMIDENT
# 187   Breast-MRI-NACT-Pilot     TU        UCSF-BR-47    187     T01  TUMIDENT
# 209   Breast-MRI-NACT-Pilot     TU        UCSF-BR-53    209     T01  TUMIDENT
# 219   Breast-MRI-NACT-Pilot     TU        UCSF-BR-57    219     T01  TUMIDENT
# 677                  I-Spy1     TU        ISPY1_1123    677     T01  TUMIDENT
# 1102                Ivy-Gap     TU               W10   1102     T01  TUMIDENT
# 1365                Ivy-Gap     TU                W4   1365     T01  TUMIDENT
# 1478              TCGA-BRCA     TU      TCGA-AO-A12E   1478     T01  TUMIDENT
# 1496              TCGA-BRCA     TU      TCGA-AR-A24X   1496     T01  TUMIDENT
# 1510              TCGA-BRCA     TU      TCGA-BH-A0BT   1510     T01  TUMIDENT
# ...

# %%
plot_model(knn)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>
#
#
#             <div id="56efb4de-3be0-42dc-abed-3bef8c24ee7b" class="plotly-graph-div" style="height:800px; width:900px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("56efb4de-3be0-42dc-abed-3bef8c24ee7b")) {
#                     Plotly.newPlot(
# ...

# %%
plot_model(knn,plot = 'umap')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>
#
#
#             <div id="03534e18-65e3-4bbd-9b2e-cdda5a3128fe" class="plotly-graph-div" style="height:800px; width:900px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("03534e18-65e3-4bbd-9b2e-cdda5a3128fe")) {
#                     Plotly.newPlot(
# ...

# %%
unseen_predictions = predict_model(knn, data=data_unseen)
unseen_predictions.head()
# Out:
#                  STUDYID DOMAIN           USUBJID  TUSEQ TULNKID  TUTESTCD  \
# 0       Breast Diagnosis     TU  BreastDx-01-0005      6     T01  TUMIDENT
# 1       Breast Diagnosis     TU  BreastDx-01-0013     18     T01  TUMIDENT
# 2       Breast Diagnosis     TU  BreastDx-01-0038     49     T01  TUMIDENT
# 3  Breast-MRI-NACT-Pilot     TU        UCSF-BR-11     87     T01  TUMIDENT
# 4  Breast-MRI-NACT-Pilot     TU        UCSF-BR-11     90     T01  TUMIDENT
#
#                  TUTEST TUORRES   TULOC  TULAT TUMETHOD      TUDTC  Label  \
# 0  Tumor Identification  TARGET  BREAST  RIGHT      MRI  6/24/2008      0
# 1  Tumor Identification  TARGET  BREAST    NaN      MRI  8/19/2008      0
# 2  Tumor Identification  TARGET  BREAST   LEFT      MRI  8/26/2008      0
# 3  Tumor Identification  TARGET  BREAST   LEFT      MRI  7/15/1992      0
# 4  Tumor Identification  TARGET  BREAST   LEFT      MRI  6/10/1992      0
#
#       Score
# 0  0.000000
# 1  1.414214
# 2  0.000000
# 3  1.414214
# ...

# %%
label_1_unseen = unseen_predictions['Label'] == 1
unseen_predictions[label_1_unseen]
# Out:
#       STUDYID DOMAIN       USUBJID  TUSEQ TULNKID  TUTESTCD  \
# 80  TCGA-BRCA     TU  TCGA-E2-A1IG   1582     T01  TUMIDENT
#
#                   TUTEST TUORRES   TULOC TULAT TUMETHOD     TUDTC  Label  \
# 80  Tumor Identification  TARGET  BREAST   NaN      MRI  9/1/2001      1
#
#     Score
# 80    2.0

# %%
data_predictions = predict_model(knn, data = data)
data_predictions.head()
# Out:
#                  STUDYID DOMAIN       USUBJID  TUSEQ TULNKID  TUTESTCD  \
# 0              TCGA-BRCA     TU  TCGA-BH-A18H   1547     T01  TUMIDENT
# 1                Ivy-Gap     TU           W53   1430     T01  TUMIDENT
# 2                Ivy-Gap     TU           W11   1128     T01  TUMIDENT
# 3  Breast-MRI-NACT-Pilot     TU    UCSF-BR-47    189     T01  TUMIDENT
# 4                 I-Spy1     TU    ISPY1_1213   1001     T01  TUMIDENT
#
#                  TUTEST TUORRES   TULOC TULAT TUMETHOD      TUDTC  Label  \
# 0  Tumor Identification  TARGET  BREAST   NaN      MRI   2/3/2004      0
# 1  Tumor Identification  TARGET   BRAIN   NaN      MRI  6/10/2000      0
# 2  Tumor Identification  TARGET   BRAIN   NaN      MRI   6/1/1999      0
# 3  Tumor Identification  TARGET  BREAST  LEFT      MRI   7/4/1991      0
# 4  Tumor Identification  TARGET  BREAST  LEFT      MRI  3/10/1988      0
#
#       Score
# 0  1.414214
# 1  0.000000
# 2  1.414214
# 3  0.000000
# 4  0.000000

# %%
save_model(knn,'TU_KNN_Breast_Cancer')
# Out:
# Transformation Pipeline and Model Succesfully Saved
